# %%
string1 = ['sfs__k_features', [(2,13)]]
string2 = ['n_estimators',[1,5,10,50,100,250,500,1000]]
string3 = ['max_depth',[2,5,10,20,50,75,150]]

# %%
def make_params(string0,string1,string2,string3=None):
    params = []
    if string3:
        for el2 in string3[1]:
            for el in string2[1]:
                params.append({string1[0]:string1[1],
                              string0[0]+'__'+string2[0]:[el],
                              string0[1]+'__estimator__'+string2[0]:[el],
                              string0[0]+'__'+string3[0]:[el2],
                              string0[1]+'__estimator__'+string3[0]:[el2]})
    else:
        for el in string2[1]:
            params.append({string1[0]:string1[1],
                         string0[0]+'__'+string2[0]:[el],
                         string0[1]+'__estimator__'+string2[0]:[el]})
    return params

# %%
def sfs_gridsearch_params(list_of_names, **kwargs):
    params = []
    for name, space in kwargs.items():
        params.append[{}]

# %%
param_grid_rfr_sfs = make_params(['rfc','sfs'],string1,string2,string3)
param_grid_rfr_sfs
# Out:
# [{'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [2],
#   'sfs__estimator__max_depth': [2]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [5],
#   'sfs__estimator__max_depth': [5]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [10],
#   'sfs__estimator__max_depth': [10]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [20],
#   'sfs__estimator__max_depth': [20]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [50],
#   'sfs__estimator__max_depth': [50]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [75],
#   'sfs__estimator__max_depth': [75]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1],
#   'sfs__estimator__n_estimators': [1],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [5],
#   'sfs__estimator__n_estimators': [5],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [10],
#   'sfs__estimator__n_estimators': [10],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [50],
#   'sfs__estimator__n_estimators': [50],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [100],
#   'sfs__estimator__n_estimators': [100],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [250],
#   'sfs__estimator__n_estimators': [250],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [500],
#   'sfs__estimator__n_estimators': [500],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]},
#  {'sfs__k_features': [(2, 13)],
#   'rfc__n_estimators': [1000],
#   'sfs__estimator__n_estimators': [1000],
#   'rfc__max_depth': [150],
#   'sfs__estimator__max_depth': [150]}]
